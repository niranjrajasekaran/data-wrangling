# %%
import pandas as pd

# %%
# To read a CSV or txt file we can use read_csv method of pandas
df = pd.read_csv('breast.csv')

# %%
# To see only a top few rows we can use df.head()
df.head()
# Out:
#    patient_id  clump_thickness  cell_size_uniformity  cell_shape_uniformity  \
# 0     1000025              5.0                   1.0                      1
# 1     1002945              5.0                   4.0                      4
# 2     1015425              3.0                   1.0                      1
# 3     1016277              6.0                   8.0                      8
# 4     1017023              4.0                   1.0                      1
#
#    marginal_adhesion  single_ep_cell_size bare_nuclei  bland_chromatin  \
# 0                  1                    2           1              3.0
# 1                  5                    7          10              3.0
# 2                  1                    2           2              3.0
# 3                  1                    3           4              3.0
# 4                  3                    2           1              3.0
#
#    normal_nucleoli  mitoses   class doctor_name
# ...

# %%
# This txt file have all columns and rows seperated via a space and not by comma
# By default in read_csv seperator is ','
df_t = pd.read_csv('breast.txt', sep=' ')

# %%
df_t.head()
# Out:
#          patient_id  clump_thickness  cell_size_uniformity  \
# 1000025         5.0              1.0                     1
# 1002945         5.0              4.0                     4
# 1015425         3.0              1.0                     1
# 1016277         6.0              8.0                     8
# 1017023         4.0              1.0                     1
#
#          cell_shape_uniformity  marginal_adhesion single_ep_cell_size  \
# 1000025                      1                  2                   1
# 1002945                      5                  7                  10
# 1015425                      1                  2                   2
# 1016277                      1                  3                   4
# 1017023                      3                  2                   1
#
#          bare_nuclei  bland_chromatin  normal_nucleoli mitoses class  \
# 1000025          3.0              1.0                1  benign   Dr.
# ...

# %%
# To read a html file in pandas
# For this we need to install html5lib
import html5lib

list_of_dfs = pd.read_html('https://en.wikipedia.org/wiki/States_and_union_territories_of_India')

# %%
# This will be a list of pandas dataframes, manually check and get the index of any format required
list_of_dfs
# Out:
# [  States and union territories of India  \
#  0                              Category
#  1                              Location
#  2                                Number
#  3                           Populations
#  4                                 Areas
#  5                            Government
#  6                          Subdivisions
#
#               States and union territories of India.1
#  0                                   Federated states
#  1                                  Republic of India
#  2                       28 States8 Union territories
#  3  States: Sikkim - 610,577 (lowest); Uttar Prade...
#  4  States: 3,702 km2 (1,429 sq mi) Goa – 342,269 ...
#  5  State governments, Union government (Union ter...
#  6                               Districts, Divisions  ,
# ...

# %%
# Here we are trying to get the table from the html page
list_of_dfs[3]
# Out:
#                 State ISO 3166-2:IN Vehiclecode           Zone  \
# 0      Andhra Pradesh         IN-AP          AP       Southern
# 1   Arunachal Pradesh         IN-AR          AR  North-Eastern
# 2               Assam         IN-AS          AS  North-Eastern
# 3               Bihar         IN-BR          BR        Eastern
# 4        Chhattisgarh         IN-CT          CG        Central
# 5                 Goa         IN-GA          GA        Western
# 6             Gujarat         IN-GJ          GJ        Western
# 7             Haryana         IN-HR          HR       Northern
# 8    Himachal Pradesh         IN-HP          HP       Northern
# 9           Jharkhand         IN-JH          JH        Eastern
# 10          Karnataka         IN-KA          KA       Southern
# 11             Kerala         IN-KL          KL       Southern
# 12     Madhya Pradesh         IN-MP          MP        Central
# 13        Maharashtra         IN-MH          MH        Western
# ...
